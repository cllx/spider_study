# %%
# 访问网站的时候设置cookie
import requests
import time
mycookie = dict(BDSID="zhadu")
req = requests.get("http://httpbin.org/cookies", cookies=mycookie)
time.sleep(3)
print(req.cookies)
print(req.text)
# Out:
# <RequestsCookieJar[]>
# {
#   "cookies": {
#     "BDSID": "zhadu"
#   }
# }

# %%
# requests session
import requests
session = requests.Session() #会话
params = {"username":"admin123", "password":"password"}
mysession = session.post("http://pythonscraping.com/pages/cookies/welcome.php", params)
print(mysession.cookies.get_dict())
mysession2 = session.get("http://pythonscraping.com/pages/cookies/profile.php")
print(mysession2.text)
# Out:
# {'loggedin': '1', 'username': 'admin123'}
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML+RDFa 1.0//EN"
#   "http://www.w3.org/MarkUp/DTD/xhtml-rdfa-1.dtd">
# <html xmlns="http://www.w3.org/1999/xhtml" xml:lang="en" version="XHTML+RDFa 1.0" dir="ltr"
#   xmlns:content="http://purl.org/rss/1.0/modules/content/"
#   xmlns:dc="http://purl.org/dc/terms/"
#   xmlns:foaf="http://xmlns.com/foaf/0.1/"
#   xmlns:og="http://ogp.me/ns#"
#   xmlns:rdfs="http://www.w3.org/2000/01/rdf-schema#"
#   xmlns:sioc="http://rdfs.org/sioc/ns#"
#   xmlns:sioct="http://rdfs.org/sioc/types#"
#   xmlns:skos="http://www.w3.org/2004/02/skos/core#"
#   xmlns:xsd="http://www.w3.org/2001/XMLSchema#">
#
# <head profile="http://www.w3.org/1999/xhtml/vocab">
#   <meta charset="utf-8" />
# <link rel="shortcut icon" href="http://pythonscraping.com/misc/favicon.ico" type="image/vnd.microsoft.icon" />
# <meta name="viewport" content="width=device-width, initial-scale=1" />
# <meta name="MobileOptimized" content="width" />
# ...

# %%
# requests session
import requests
session = requests.Session() #会话
params = {"emp_no":"admin", "password":"admin"}
mysession = session.post("http://demo.smeoa.com/index.php?m=&c=public&a=check_login", params)
print(mysession.cookies.get_dict())
mysession2 = session.get("http://demo.smeoa.com")
print(mysession2.text)
# Out:
# {}
# ﻿<!DOCTYPE html>
# <html>
# 	<head>
# 		<meta charset="utf-8">
# 		<title>OA系统</title>
# 		<meta name="renderer" content="webkit">
# 		<meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
# 		<meta name="viewport" content="width=device-width,initial-scale=1,maximum-scale=1,user-scalable=no">
# 		<meta name="apple-mobile-web-app-status-bar-style" content="black">
# 		<meta name="apple-mobile-web-app-capable" content="yes">
# 		<meta name="format-detection" content="telephone=no">
# 		<link rel="stylesheet" href="Public/layui/css/layui.css"  media="all">
# 		<link rel="stylesheet" href="Public/layui/css/layui.mobile.css">
# 		<link rel="stylesheet" href="Public/layui/css/global.css" media="all">
# 		<link rel="stylesheet" href="Public/layui/font-awesome/css/font-awesome.min.css" media="all">
# 	</head>
# 	<script type="text/javascript">
# 	var upload_url = "/index.php?m=&c=Index&a=upload";
# 	var del_url = "/index.php?m=&c=Index&a=del_file";
# 	var app_path = "";
# ...

# %%
import requests
import requests.auth
# 登录路由器模拟
auth = requests.auth.HTTPBasicAuth("ryan", "password")
req = requests.post(url="http://pythonscraping.com/pages/auth/login.php", auth=auth)
print(req.text)
# Out:
# <p>Hello ryan.</p><p>You entered password as your password.</p>

# %%
# 抓取ip信息的json格式数据
import requests
import requests.auth
req = requests.get(url="https://api.ip2country.info/ip?121.35.9.66", verify=False)
print(req.text)
print("........%s" %(req.json().get("countryName"))) #抓取json，实例化返回国家名字
# Out:
# e:\anaconda3\lib\site-packages\urllib3\connectionpool.py:858: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# {
# 	"countryCode": "CN",
# 	"countryCode3": "CHN",
# 	"countryName": "China",
# 	"countryEmoji": "🇨🇳"
# }
#
# ........China

# %%
# 模拟手机京东
from selenium import webdriver
import time
import lxml.etree
import lxml
import requests

driver = webdriver.Chrome()
driver.get("https://passport.jd.com/new/login.aspx?ReturnUrl=https%3A%2F%2Fwww.jd.com%2F")
time.sleep(3)
elem = driver.find_element_by_xpath("//*[@class=\"login-tab login-tab-r\"]/a")
elem.click()
time.sleep(5)
user = driver.find_element_by_id("loginname")
password = driver.find_element_by_id("nloginpwd")
submit = driver.find_element_by_id("loginsubmit")
user.clear()
password.clear()
time.sleep(1)
user.send_keys("18981651893")
password.send_keys("long1995814")
time.sleep(2)
submit.click()
time.sleep(10) #等待页面加载
print("开始会话")
req = requests.session() #会话
cookies = driver.get_cookies() #抓取全部cookie
for cookie in cookies:
    req.cookies.set(cookie['name'], cookie["value"])
newpage = req.get("https://cart.jd.com/cart.action")
req.headers.clear() #清空头
print("会话完成")
print(newpage.text) #页面
mytree = lxml.etree.HTML(newpage.text)
print(mytree.xpath("//*[@class=\"cell p-price\"]/strong/text()"))
time.sleep(10)
driver.close()
# Out:
# 开始会话
# 会话完成
# <!DOCTYPE html>
# <html>
# <head>
# <meta charset="utf-8" />
# <meta name="renderer" content="webkit" />
# <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1" />
# <title>我的购物车 - 京东商城</title>
#         <link type="text/css" rel="stylesheet"  href="//misc.360buyimg.com/jdf/1.0.0/unit/??ui-base/5.0.0/ui-base.css,shortcut/5.0.0/shortcut.css,global-header/5.0.0/global-header.css,myjd/5.0.0/myjd.css,nav/5.0.0/nav.css,shoppingcart/5.0.0/shoppingcart.css,global-footer/5.0.0/global-footer.css,service/5.0.0/service.css"/>
#         <script type="text/javascript" src="//misc.360buyimg.com/jdf/lib/jquery-1.6.4.js"></script>
#         <script type="text/javascript" src="//misc.360buyimg.com/jdf/1.0.0/unit/base/5.0.0/base.js"></script>
#         <link source="widget" href="//misc.360buyimg.com/user/cart/??/widget/no-login/no-login.css" rel="stylesheet" type="text/css">
# ...

# %%
# 模拟登录csdn(使用urllib，而不是requests)
from selenium import webdriver
import time
import lxml.etree
import lxml
import urllib
import requests

driver = webdriver.Chrome()
driver.get("https://passport.csdn.net/account/login?")
time.sleep(3)
zhanghao_link = driver.find_element_by_xpath("//*[@class=\"text-tab border-right\"]/a")
zhanghao_link.click()
time.sleep(3)
user = driver.find_element_by_id("all")
password = driver.find_element_by_id("password-number")
user.clear()
password.clear()
time.sleep(1)
user.send_keys("18981651893")
password.send_keys("long1995814")
time.sleep(2)
submit = driver.find_element_by_xpath("//*[@class=\"btn btn-primary\"]")
submit.click()
time.sleep(10) #等待页面加载
print("开始会话")
req = requests.session() #会话
cookies = driver.get_cookies() #抓取全部cookie
driver.close()

url = "https://www.csdn.net/"
headers = {
    "authority": "msg.csdn.net",
    "method": "POST",
    "path": "/v1/web/message/view/unread",
    "scheme": "https",
    "accept": "application/json, text/javascript, */*; q=0.01",
    #"accept-encoding": "gzip, deflate, br",
    "accept-language": "zh-CN,zh;q=0.9",
    "content-length": "0",
    u"cookie": u"uuid_tt_dd=10_30621378940-1522165664844-183024; UN=qq_29526753; smidV2=201805291645351c9aab451cc358a4b0e418ec091895ad00df2f46fc567a460; dc_session_id=10_1540364214059.672737; c-login-auto=5; Hm_ct_6bcd52f51e9b3dce32bec4a3997715ac=1788*1*PC_VC!5744*1*qq_29526753; MSG-SESSION=c20d2b73-21b5-4556-92de-d57c9421db46; Hm_lvt_6bcd52f51e9b3dce32bec4a3997715ac=1547814255,1547866143,1547886266,1548385044; Hm_lpvt_6bcd52f51e9b3dce32bec4a3997715ac=1548385048; SESSION=a3ad5073-f471-45cf-854d-34e9452c833c; dc_tos=plv9jw; UserName=qq_29526753; UserInfo=1a2cd8a0f3bb46248c8908bf891ee09f; UserToken=1a2cd8a0f3bb46248c8908bf891ee09f; UserNick=qq_29526753; AU=8AA; BT=1548385069541",
    "origin": "https://www.csdn.net",
    "referer": "https://www.csdn.net/",
    "user-agent": "Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/72.0.3626.7 Safari/537.36"
}
req = urllib.request.Request(url, headers=headers)
response = urllib.request.urlopen(req)
pagesource = response.read()
print(pagesource)
# Out:
# 开始会话
# ...

# %%
# coding:utf-8
import requests
import time
user_agent = '''User-Agent:Mozilla/5.0 (compatible; MSIE 9.0; Windows NT 6.1; Trident/5.0);'''
headers = {'User-Agent': user_agent}
mycookie = dict(BDIDUID = "zhadu") #模拟登陆
r = requests.get("http://www.baidu.com", headers=headers, cookies=mycookie)
print(r.cookies)
for cookie in r.cookies.keys(): #百度所有的cookie
    print(cookie)
    print(r.cookies.get(cookie))
# Out:
# <RequestsCookieJar[<Cookie H_PS_PSSID=1460_21091_18559_28328_26350 for .baidu.com/>, <Cookie delPer=0 for .baidu.com/>, <Cookie BDSVRTM=0 for www.baidu.com/>, <Cookie BD_HOME=0 for www.baidu.com/>]>
# H_PS_PSSID
# 1460_21091_18559_28328_26350
# delPer
# 0
# BDSVRTM
# 0
# BD_HOME
# 0

# %%
import requests
session = requests.session()
try:
    req = session.get("http://v57.demo.dedecms.com/dede/login.php?", allow_redirects=True)
    datas = {"gotopage": "/dede/index.php",
             "dopost": "login",
             "adminstyle": "newdedecms",
             "userid": "admin",
             "pwd": "admin",
             "sml": ""}
    res = session.post("http://v57.demo.dedecms.com/dede/login.php?", data=datas)
    print(res.text)
    print("-------------------------------------------------------")
    res = session.get("http://v57.demo.dedecms.com/member/")
    print(res.text)
except requests.exceptions.ConnectionError as e:
    print(e)
    print("访问不了")
# Out:
# HTTPConnectionPool(host='v57.demo.dedecms.com', port=80): Max retries exceeded with url: /dede/login.php (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x0000021FADA57BE0>: Failed to establish a new connection: [WinError 10061] 由于目标计算机积极拒绝，无法连接。',))
# 访问不了
